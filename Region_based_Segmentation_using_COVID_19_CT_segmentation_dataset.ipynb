# %% [markdown]
# ## Region based segmentation using annotated public "COVID-19 CT segmentation dataset"
#
# * The algorithm explores lung region based segmetnation.
# * The dice coeffecient was used to measure the preformance of the segmetnation method.
# * The annotated CT images at http://medicalsegmentation.com/covid19/
# was used.
# * From the annotated dataset: the Image volumes (308 Mb), and the Lung masks (1 Mb) were used to validate the segmentaiton performacne.

# %%
import os, glob
import numpy as np
import matplotlib.pyplot as plt
import cv2
import nibabel as nib

import tensorflow as tf
 
from tensorflow import keras

# %%
from PIL import Image as im
import skimage
from skimage.filters import sobel

# %%
from skimage import morphology
from skimage.feature import canny
#from scipy import ndimage as ndi
from skimage import io
from skimage.exposure import histogram

# %%
# Mounting my google drive
from google.colab import drive

# %%
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Slicing and Saving

# %%
## The path here include the image volumes (308MB) and the lung masks (1MB) were extracted from the COVID-19 CT segmentation dataset
dataInputPath = '/content/gdrive/MyDrive/Segmentation/volumes/'
imagePathInput = os.path.join(dataInputPath, 'img/') ## Image volumes were exctracted to this subfolder
maskPathInput = os.path.join(dataInputPath, 'mask/') ## lung masks were exctracted to this subfolder

# %%
# Preparing the outputpath for slicing the CT volume from the above data
dataOutputPath = '/content/gdrive/MyDrive/Segmentation/slices/'
imageSliceOutput = os.path.join(dataOutputPath, 'img/') ## Image volume slices will be placed here
maskSliceOutput = os.path.join(dataOutputPath, 'mask/') ## Annotated masks slices will be placed here

# %%
# Slicing only in Z direction
# Slices in Z direction shows the required lung area
SLICE_X = False
SLICE_Y = False
SLICE_Z = True

SLICE_DECIMATE_IDENTIFIER = 3

# %%
# Choosing normalization boundaries suitable from the chosen images
HOUNSFIELD_MIN = -1020
HOUNSFIELD_MAX = 2995
HOUNSFIELD_RANGE = HOUNSFIELD_MAX - HOUNSFIELD_MIN

# Normalizing the images
def normalizeImageIntensityRange (img):
    img[img < HOUNSFIELD_MIN] = HOUNSFIELD_MIN
    img[img > HOUNSFIELD_MAX] = HOUNSFIELD_MAX
    return (img - HOUNSFIELD_MIN) / HOUNSFIELD_RANGE

nImg = normalizeImageIntensityRange(img)
np.min(nImg), np.max(nImg), nImg.shape, type(nImg)

# Reading image or mask volume
def readImageVolume(imgPath, normalize=True):
    img = nib.load(imgPath).get_fdata()
    if normalize:
        return normalizeImageIntensityRange(img)
    else:
        return img
    
readImageVolume(imgPath, normalize=False)
readImageVolume(maskPath, normalize=False)

# Slicing image in all directions and save
def sliceAndSaveVolumeImage(vol, fname, path):
    (dimx, dimy, dimz) = vol.shape
    print(dimx, dimy, dimz)
    cnt = 0
    if SLICE_X:
        cnt += dimx
        print('Slicing X: ')
        for i in range(dimx):
            saveSlice(vol[i,:,:], fname+f'-slice{str(i).zfill(SLICE_DECIMATE_IDENTIFIER)}_x', path)
            
    if SLICE_Y:
        cnt += dimy
        print('Slicing Y: ')
        for i in range(dimy):
            saveSlice(vol[:,i,:], fname+f'-slice{str(i).zfill(SLICE_DECIMATE_IDENTIFIER)}_y', path)
            
    if SLICE_Z:
        cnt += dimz
        print('Slicing Z: ')
        for i in range(dimz):
            saveSlice(vol[:,:,i], fname+f'-slice{str(i).zfill(SLICE_DECIMATE_IDENTIFIER)}_z', path)
    return cnt

# Saving volume slices to file
def saveSlice (img, fname, path):
    img = np.uint8(img * 255)
    fout = os.path.join(path, f'{fname}.png')
    cv2.imwrite(fout, img)
    print(f'[+] Slice saved: {fout}', end='\r')

# %%
# Reading and processing image volumes for TEST images
for index, filename in enumerate(sorted(glob.iglob(imagePathInput+'*.nii.gz'))):
    img = readImageVolume(filename, True)
    print(filename, img.shape, np.sum(img.shape), np.min(img), np.max(img))
    numOfSlices = sliceAndSaveVolumeImage(img, 't'+str(index), imageSliceOutput)
    print(f'\n{filename}, {numOfSlices} slices created \n')

# Reading and processing image mask volumes for TEST masks
for index, filename in enumerate(sorted(glob.iglob(maskPathInput+'*.nii.gz'))):
    img = readImageVolume(filename, False)
    print(filename, img.shape, np.sum(img.shape), np.min(img), np.max(img))
    numOfSlices = sliceAndSaveVolumeImage(img, 't'+str(index), maskSliceOutput)
    print(f'\n{filename}, {numOfSlices} slices created \n')
# Out:
# /content/gdrive/MyDrive/Segmentation/volumes/img/1.nii.gz (630, 630, 45) 1305 0.0 0.3070329411982896
# 630 630 45
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t0-slice044_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/1.nii.gz, 45 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/2.nii.gz (630, 630, 39) 1299 0.0 0.29788061310612546
# 630 630 39
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t1-slice038_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/2.nii.gz, 39 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/3.nii.gz (630, 630, 418) 1678 0.0 0.28805189310836316
# 630 630 418
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t2-slice417_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/3.nii.gz, 418 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/4.nii.gz (630, 630, 39) 1299 0.0 0.29359098175542886
# 630 630 39
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t3-slice038_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/4.nii.gz, 39 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/5.nii.gz (630, 630, 66) 1326 0.0 0.29295800233985836
# 630 630 66
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t4-slice065_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/5.nii.gz, 66 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/6.nii.gz (630, 630, 42) 1302 0.0 0.29983340746735876
# 630 630 42
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t5-slice041_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/6.nii.gz, 42 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/7.nii.gz (630, 630, 42) 1302 0.0 0.29788061310612546
# 630 630 42
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t6-slice041_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/7.nii.gz, 42 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/8.nii.gz (630, 630, 45) 1305 0.0 0.3115153501517746
# 630 630 45
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t7-slice044_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/8.nii.gz, 45 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/9.nii.gz (630, 630, 93) 1353 0.0 0.3265356840558842
# 630 630 93
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t8-slice092_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/9.nii.gz, 93 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/1.nii.gz (630, 630, 45) 1305 0.0 1.0
# 630 630 45
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t0-slice044_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/1.nii.gz, 45 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/2.nii.gz (630, 630, 39) 1299 0.0 1.0
# 630 630 39
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t1-slice038_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/2.nii.gz, 39 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/3.nii.gz (630, 630, 418) 1678 0.0 1.0
# 630 630 418
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t2-slice417_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/3.nii.gz, 418 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/4.nii.gz (630, 630, 39) 1299 0.0 1.0
# 630 630 39
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t3-slice038_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/4.nii.gz, 39 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/5.nii.gz (630, 630, 66) 1326 0.0 1.0
# 630 630 66
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t4-slice065_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/5.nii.gz, 66 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/6.nii.gz (630, 630, 42) 1302 0.0 1.0
# 630 630 42
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t5-slice041_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/6.nii.gz, 42 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/7.nii.gz (630, 630, 42) 1302 0.0 1.0
# 630 630 42
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t6-slice041_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/7.nii.gz, 42 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/8.nii.gz (630, 630, 45) 1305 0.0 1.0
# 630 630 45
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t7-slice044_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/8.nii.gz, 45 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/9.nii.gz (630, 630, 93) 1353 0.0 1.0
# 630 630 93
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t8-slice092_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/9.nii.gz, 93 slices created

# %%
# Exploring the data 
imgPath = os.path.join(imagePathInput, '1.nii.gz')
img = nib.load(imgPath).get_fdata()
np.min(img), np.max(img), img.shape, type(img)


maskPath = os.path.join(maskPathInput, '1.nii.gz')
mask = nib.load(maskPath).get_fdata()
np.min(mask), np.max(mask), mask.shape, type(mask)

# Showing image slice
imgSlice = mask[:,:,20]
plt.imshow(imgSlice, cmap='gray')
plt.show()

# %% [markdown]
# ## Histogram based Thresholding Segmentation

# %%
## Reading the image in gray scale and gussian blurring
n= cv2.imread("/content/gdrive/MyDrive/Segmentation/slices/img/t0-slice008_z.png")
n= cv2.cvtColor(n, cv2.COLOR_BGR2GRAY)
n = cv2.GaussianBlur(n, (5, 5), 0)

# Checking image histogram for extreme values to be used as markers later 5&70
hist, hist_centers = histogram(n)

fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(n, cmap=plt.cm.gray)
axes[0].axis('off')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('histogram of gray values')

# The sobel edge detector
#img = canny(n) 
img = sobel(n)

fig, ax = plt.subplots(figsize=(4, 3))
ax.imshow(img, cmap=plt.cm.gray)
ax.set_title('Canny detector')
ax.axis('off')

# The markers chosen from the histogram of the image
markers = np.zeros_like(n)
markers[n < 5] = 1  # Chosen extreme from histogram
markers[n > 70] = 2  # Chosen extreme from histogram

fig, ax = plt.subplots(figsize=(4, 3))
ax.imshow(img, cmap=plt.cm.gray)
ax.set_title('filling the holes')
ax.axis('off')

#img = cv2.erode(img, None, iterations=2)
#img = cv2.dilate(img, None, iterations=2)

# water shed segmentaiton
segmentation_coins = segmentation.watershed(img, markers)

fig, ax = plt.subplots(figsize=(4, 3))
ax.imshow(segmentation_coins, cmap=plt.cm.gray)
ax.set_title('removing small objects')
ax.axis('off')

# Modifying the background to exctract the segmetned lungs
ret, gray = ret, gray = cv2.threshold(segmentation_coins.astype(np.uint8), 1, 255, cv2.THRESH_BINARY)
for x in range(gray.shape[1]):
    # Fill dark top pixels:
 if gray[0, x] == 0:
      cv2.floodFill(gray, None, seedPoint=(x, 0), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color
    # Fill dark bottom pixels:
 if gray[-1, x] == 0:
      cv2.floodFill(gray, None, seedPoint=(x, gray.shape[0]-1), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color

for y in range(gray.shape[0]):
    # Fill dark left side pixels:
 if gray[y, 0] == 0:
      cv2.floodFill(gray, None, seedPoint=(0, y), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color
    # Fill dark right side pixels:
 if gray[y, -1] == 0:
      cv2.floodFill(gray, None, seedPoint=(gray.shape[1]-1, y), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color

fig, ax = plt.subplots()
plt.imshow(gray, cmap='gray')
ax.set_title('segmented Lungs')
plt.show()

# %% [markdown]
# ## Replacing images with their segmented slices in the directory

# %%
## The images in the "/content/gdrive/MyDrive/Segmentation/slices/img/*.png" will be replaced by their masks via region based segmetnation

for m in glob.glob("/content/gdrive/MyDrive/Segmentation/slices/img/*.png"):
    n=cv2.imread(m)
    n= cv2.cvtColor(n, cv2.COLOR_BGR2GRAY)
    n = cv2.GaussianBlur(n, (5, 5), 0)

    img = sobel(n)

    markers = np.zeros_like(n)
    markers[n < 5] = 1  # Chosen extreme from histogram
    markers[n > 70] = 2  # Chosen extreme from histogram

    segmentation_coins = segmentation.watershed(img, markers)
 
    # Modifying the background to exctract the segmetned lungs
    ret, gray = ret, gray = cv2.threshold(segmentation_coins.astype(np.uint8), 1, 255, cv2.THRESH_BINARY)
    for x in range(gray.shape[1]):
    # Fill dark top pixels:
     if gray[0, x] == 0:
      cv2.floodFill(gray, None, seedPoint=(x, 0), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color
    # Fill dark bottom pixels:
     if gray[-1, x] == 0:
      cv2.floodFill(gray, None, seedPoint=(x, gray.shape[0]-1), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color

    for y in range(gray.shape[0]):
    # Fill dark left side pixels:
     if gray[y, 0] == 0:
      cv2.floodFill(gray, None, seedPoint=(0, y), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color
    # Fill dark right side pixels:
     if gray[y, -1] == 0:
      cv2.floodFill(gray, None, seedPoint=(gray.shape[1]-1, y), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color
    
    file_name, file_ext = os.path.splitext(m)
    gray = im.fromarray(gray)
    #img = im.fromarray(img)
    gray.save('{}.png'.format(file_name))

# %% [markdown]
# ## Using Dice Coeffecient for measuring the perforrmamce of the segmetnaton

# %%
## Segmetnation Quantifying Measure (Dice coeffecient)

def dice_coef(img, img2):
        if img.shape != img2.shape:
            raise ValueError("Shape mismatch: img and img2 must have to be of the same shape.")
        else:
            
            lenIntersection=0
            
            for i in range(img.shape[0]):
                for j in range(img.shape[1]):
                    if ( np.array_equal(img[i][j],img2[i][j]) ):
                        lenIntersection+=1
             
            lenimg=img.shape[0]*img.shape[1]
            lenimg2=img2.shape[0]*img2.shape[1]  
            value = (2. * lenIntersection  / (lenimg + lenimg2))
        return value

# %%
## Ground Truth Mask
img = cv2.imread('/content/gdrive/MyDrive/Segmentation/slices/mask/t0-slice012_z.png')

hist, hist_centers = histogram(img)
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(img, cmap=plt.cm.gray)
axes[0].axis('off')
axes[0].set_title('Ground Truth')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('Ground Truth Grey Values')

#print(img)
img = np.asarray(img).astype(np.bool)
#print(img)
print(img.shape)
#print('_'*40)

## Predicted mask
img2 = cv2.imread('/content/gdrive/MyDrive/Segmentation/slices/img/t0-slice012_z.png')
img2 = cv2.subtract(250, img2)

hist, hist_centers = histogram(img2)
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(img2, cmap=plt.cm.gray)
axes[0].axis('off')
axes[0].set_title('Predicted Mask')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('Pridited mask Grey Values')

#print(img2)
img2 = np.asarray(img2).astype(np.bool)

#print(img2)
print(img2.shape)
#print('%'*40)

value = dice_coef(img, img2)
print("Dice coeffecient value is", value)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (630, 630, 3)
# (630, 630, 3)
# Dice coeffecient value is 0.8577651801461326

# %%
## Checking Dice values for all slices in the dataset (image volumes and lung musks)
GT_path = '/content/gdrive/MyDrive/Segmentation/slices/mask/'
pred_path = '/content/gdrive/MyDrive/Segmentation/slices/img/'

import os

# specify the img directory path
path = "path/to/img/folder/"

# list files in img directory
files = os.listdir(GT_path)
files2 = os.listdir(pred_path)

dicee = []
for file in files:
    # make sure file is an image
    if file.endswith('.png'):
      for filee in files2:
        if filee == file:
          ## Ground Truth Mask
          img = cv2.imread(GT_path + file)
          img = np.asarray(img).astype(np.bool)

          ## Predicted mask
          img2 = cv2.imread(pred_path + filee)
          img2 = cv2.subtract(250, img2)
          img2 = np.asarray(img2).astype(np.bool)

          value = dice_coef(img, img2)
          print("Dice coeffecient value is", value, "\n") 
          dicee.append(value)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Dice coeffecient value is 0.9783371126228269
#
# Dice coeffecient value is 0.9926732174351222
#
# Dice coeffecient value is 0.9631242126480222
#
# Dice coeffecient value is 0.9503955656336609
#
# Dice coeffecient value is 0.8429931972789115
#
# Dice coeffecient value is 0.93623330813807
#
# Dice coeffecient value is 0.8400050390526581
#
# Dice coeffecient value is 0.8439027462836987
#
# Dice coeffecient value is 0.8400730662635425
#
# Dice coeffecient value is 0.8397178130511463
#
# Dice coeffecient value is 0.8411438649533888
#
# Dice coeffecient value is 0.8429528848576467
#
# Dice coeffecient value is 0.8419727891156462
#
# Dice coeffecient value is 0.8412018140589569
#
# Dice coeffecient value is 0.8410330057949106
#
# Dice coeffecient value is 0.8394280675233056
#
# Dice coeffecient value is 0.843466868228773
#
# Dice coeffecient value is 0.8317031997984379
#
# Dice coeffecient value is 0.8338070042831948
#
# Dice coeffecient value is 0.8313932980599648
#
# Dice coeffecient value is 0.8291710758377425
#
# Dice coeffecient value is 0.8260846560846561
#
# Dice coeffecient value is 0.8279465860418241
#
# Dice coeffecient value is 0.8204761904761905
#
# Dice coeffecient value is 0.8346837994457043
#
# Dice coeffecient value is 0.8491106072058453
#
# Dice coeffecient value is 0.8219022423784329
#
# Dice coeffecient value is 0.9449307130259511
#
# Dice coeffecient value is 0.8169690098261527
#
# Dice coeffecient value is 0.9119375157470395
#
# Dice coeffecient value is 0.8861048122952885
#
# Dice coeffecient value is 0.8655656336608718
#
# Dice coeffecient value is 0.9617661879566641
#
# Dice coeffecient value is 0.9964852607709751
#
# Dice coeffecient value is 0.9936457545981355
#
# Dice coeffecient value is 0.9676341647770219
#
# Dice coeffecient value is 0.9772537163013354
#
# Dice coeffecient value is 0.9921239606953892
#
# Dice coeffecient value is 0.9926253464348702
#
# Dice coeffecient value is 0.9969967246157723
#
# Dice coeffecient value is 0.9813051146384479
#
# Dice coeffecient value is 0.9522297808012093
#
# Dice coeffecient value is 0.9965306122448979
#
# Dice coeffecient value is 0.9242907533383724
#
# Dice coeffecient value is 0.8846863189720332
#
# Dice coeffecient value is 0.8291106072058453
#
# Dice coeffecient value is 0.8104232804232804
#
# Dice coeffecient value is 0.7891710758377425
#
# Dice coeffecient value is 0.7870194003527337
#
# Dice coeffecient value is 0.7965910808767952
#
# Dice coeffecient value is 0.7997757621567145
#
# Dice coeffecient value is 0.7909826152683296
#
# Dice coeffecient value is 0.7934971025447216
#
# Dice coeffecient value is 0.799949609473419
#
# Dice coeffecient value is 0.8028747795414463
#
# Dice coeffecient value is 0.807490551776266
#
# Dice coeffecient value is 0.8038548752834467
#
# Dice coeffecient value is 0.813716301335349
#
# Dice coeffecient value is 0.8391131267321743
#
# Dice coeffecient value is 0.8222171831695642
#
# Dice coeffecient value is 0.8450667674477198
#
# Dice coeffecient value is 0.8310254472159234
#
# Dice coeffecient value is 0.8559813555051651
#
# Dice coeffecient value is 0.8697178130511464
#
# Dice coeffecient value is 0.8856437389770723
#
# Dice coeffecient value is 0.9015973796926178
#
# Dice coeffecient value is 0.9222323003275384
#
# Dice coeffecient value is 0.9435374149659864
#
# Dice coeffecient value is 0.95859410430839
#
# Dice coeffecient value is 0.9712370874275637
#
# Dice coeffecient value is 0.986981607457798
#
# Dice coeffecient value is 0.998490803728899
#
# Dice coeffecient value is 0.9984177374653566
#
# Dice coeffecient value is 0.998238851095994
#
# Dice coeffecient value is 0.9924389014865206
#
# Dice coeffecient value is 0.9924061476442428
#
# Dice coeffecient value is 0.9923859914336105
#
# Dice coeffecient value is 0.9923481985386747
#
# Dice coeffecient value is 0.9923885109599395
#
# Dice coeffecient value is 0.9930687830687831
#
# Dice coeffecient value is 0.9925799949609473
#
# Dice coeffecient value is 0.9929453262786596
#
# Dice coeffecient value is 0.9932401108591585
#
# Dice coeffecient value is 0.9936961451247166
#
# Dice coeffecient value is 0.994172335600907
#
# Dice coeffecient value is 0.9943890148652054
#
# Dice coeffecient value is 0.9949458301839255
#
# Dice coeffecient value is 0.9955857898715041
#
# Dice coeffecient value is 0.9952834467120182
#
# Dice coeffecient value is 0.9958679768203578
#
# Dice coeffecient value is 0.9960569412950365
#
# Dice coeffecient value is 0.9966061980347695
#
# Dice coeffecient value is 0.9967724867724868
#
# Dice coeffecient value is 0.9970068027210884
#
# Dice coeffecient value is 0.9971504157218443
#
# Dice coeffecient value is 0.9974981103552533
#
# Dice coeffecient value is 0.9975837742504409
#
# Dice coeffecient value is 0.9977475434618291
#
# Dice coeffecient value is 0.9965028974552784
#
# Dice coeffecient value is 0.9973620559334845
#
# Dice coeffecient value is 0.9970975056689343
#
# Dice coeffecient value is 0.9965558075081885
#
# Dice coeffecient value is 0.9967825648778029
#
# Dice coeffecient value is 0.995326278659612
#
# Dice coeffecient value is 0.995427059712774
#
# Dice coeffecient value is 0.9957394809775763
#
# Dice coeffecient value is 0.9947190728143109
#
# Dice coeffecient value is 0.9941622574955908
#
# Dice coeffecient value is 0.9923356009070294
#
# Dice coeffecient value is 0.9935903250188964
#
# Dice coeffecient value is 0.9928924162257495
#
# Dice coeffecient value is 0.9910355253212396
#
# Dice coeffecient value is 0.9917636684303351
#
# Dice coeffecient value is 0.988843537414966
#
# Dice coeffecient value is 0.9893726379440665
#
# Dice coeffecient value is 0.9902872260015118
#
# Dice coeffecient value is 0.9881053162005543
#
# Dice coeffecient value is 0.9856210632401109
#
# Dice coeffecient value is 0.986830435878055
#
# Dice coeffecient value is 0.9845049130763417
#
# Dice coeffecient value is 0.9829780801209372
#
# Dice coeffecient value is 0.9811841773746536
#
# Dice coeffecient value is 0.9790526581002772
#
# Dice coeffecient value is 0.9572763920382968
#
# Dice coeffecient value is 0.9627362055933485
#
# Dice coeffecient value is 0.9729276895943563
#
# Dice coeffecient value is 0.9769664902998236
#
# Dice coeffecient value is 0.965424540186445
#
# Dice coeffecient value is 0.9678785588309398
#
# Dice coeffecient value is 0.9600251952632906
#
# Dice coeffecient value is 0.970652557319224
#
# Dice coeffecient value is 0.9749382716049383
#
# Dice coeffecient value is 0.9547845804988662
#
# Dice coeffecient value is 0.9443587805492567
#
# Dice coeffecient value is 0.9417183169564122
#
# Dice coeffecient value is 0.9468077601410935
#
# Dice coeffecient value is 0.9392164273116654
#
# Dice coeffecient value is 0.9492768959435626
#
# Dice coeffecient value is 0.9520534139581759
#
# Dice coeffecient value is 0.9368379944570421
#
# Dice coeffecient value is 0.933869992441421
#
# Dice coeffecient value is 0.9314840010078105
#
# Dice coeffecient value is 0.9285789871504158
#
# Dice coeffecient value is 0.894620811287478
#
# Dice coeffecient value is 0.9136835474930713
#
# Dice coeffecient value is 0.8986974048878811
#
# Dice coeffecient value is 0.902915091962711
#
# Dice coeffecient value is 0.9098059964726631
#
# Dice coeffecient value is 0.9262635424540187
#
# Dice coeffecient value is 0.9202544721592341
#
# Dice coeffecient value is 0.9236507936507936
#
# Dice coeffecient value is 0.9065532879818594
#
# Dice coeffecient value is 0.9158075081884606
#
# Dice coeffecient value is 0.8908591584782061
#
# Dice coeffecient value is 0.8862358276643991
#
# Dice coeffecient value is 0.8806349206349207
#
# Dice coeffecient value is 0.8353716301335349
#
# Dice coeffecient value is 0.8374124464600655
#
# Dice coeffecient value is 0.8337994457042076
#
# Dice coeffecient value is 0.8710707986898463
#
# Dice coeffecient value is 0.831604938271605
#
# Dice coeffecient value is 0.876185437137818
#
# Dice coeffecient value is 0.8387755102040816
#
# Dice coeffecient value is 0.8207357016880826
#
# Dice coeffecient value is 0.7854295792391031
#
# Dice coeffecient value is 0.8280776014109348
#
# Dice coeffecient value is 0.8222272612748803
#
# Dice coeffecient value is 0.8252330561854372
#
# Dice coeffecient value is 0.8165129755605947
#
# Dice coeffecient value is 0.8189518770471151
#
# Dice coeffecient value is 0.8236255983875032
#
# Dice coeffecient value is 0.8266717057193248
#
# Dice coeffecient value is 0.8303300579491055
#
# Dice coeffecient value is 0.7855177626606198
#
# Dice coeffecient value is 0.7856840513983371
#
# Dice coeffecient value is 0.7859385235575712
#
# Dice coeffecient value is 0.7864449483497102
#
# Dice coeffecient value is 0.7868178382464097
#
# Dice coeffecient value is 0.8074250440917108
#
# Dice coeffecient value is 0.8018694885361553
#
# Dice coeffecient value is 0.7884555303602923
#
# Dice coeffecient value is 0.7882186948853616
#
# Dice coeffecient value is 0.7872537163013353
#
# Dice coeffecient value is 0.7888107835726883
#
# Dice coeffecient value is 0.7890375409423028
#
# Dice coeffecient value is 0.7891383219954649
#
# Dice coeffecient value is 0.7891181657848324
#
# Dice coeffecient value is 0.7888309397833208
#
# Dice coeffecient value is 0.7890980095742001
#
# Dice coeffecient value is 0.7890551776266062
#
# Dice coeffecient value is 0.7889216427311665
#
# Dice coeffecient value is 0.7891005291005291
#
# Dice coeffecient value is 0.788891408415218
#
# Dice coeffecient value is 0.7895313681027967
#
# Dice coeffecient value is 0.789294532627866
#
# Dice coeffecient value is 0.7895540438397581
#
# Dice coeffecient value is 0.7894406651549508
#
# Dice coeffecient value is 0.7887654320987655
#
# Dice coeffecient value is 0.788745275888133
#
# Dice coeffecient value is 0.7887755102040817
#
# Dice coeffecient value is 0.7889468379944571
#
# Dice coeffecient value is 0.7888636936255984
#
# Dice coeffecient value is 0.788994708994709
#
# Dice coeffecient value is 0.7932325522801713
#
# Dice coeffecient value is 0.7903376165280928
#
# Dice coeffecient value is 0.7907608969513732
#
# Dice coeffecient value is 0.7911161501637692
#
# Dice coeffecient value is 0.7915747039556563
#
# Dice coeffecient value is 0.792962962962963
#
# Dice coeffecient value is 0.7921567145376669
#
# Dice coeffecient value is 0.7926253464348703
#
# Dice coeffecient value is 0.7898614260519022
#
# Dice coeffecient value is 0.7934341143864954
#
# Dice coeffecient value is 0.7937465356512976
#
# Dice coeffecient value is 0.7944595616024187
#
# Dice coeffecient value is 0.794577979339884
#
# Dice coeffecient value is 0.7946157722348198
#
# Dice coeffecient value is 0.7939531368102797
#
# Dice coeffecient value is 0.7945704207608969
#
# Dice coeffecient value is 0.7941572184429327
#
# Dice coeffecient value is 0.7945628621819097
#
# Dice coeffecient value is 0.7946308893927941
#
# Dice coeffecient value is 0.79482741244646
#
# Dice coeffecient value is 0.796780045351474
#
# Dice coeffecient value is 0.7980498866213152
#
# Dice coeffecient value is 0.7982640463592845
#
# Dice coeffecient value is 0.7978029730410683
#
# Dice coeffecient value is 0.7968480725623582
#
# Dice coeffecient value is 0.7965180146132527
#
# Dice coeffecient value is 0.7978735197782817
#
# Dice coeffecient value is 0.7986344167296549
#
# Dice coeffecient value is 0.7986848072562358
#
# Dice coeffecient value is 0.7987276392038297
#
# Dice coeffecient value is 0.7983446712018141
#
# Dice coeffecient value is 0.8011740992693374
#
# Dice coeffecient value is 0.7994129503653313
#
# Dice coeffecient value is 0.800304862685815
#
# Dice coeffecient value is 0.8029100529100529
#
# Dice coeffecient value is 0.8023784328546233
#
# Dice coeffecient value is 0.8014613252708491
#
# Dice coeffecient value is 0.8016553287981859
#
# Dice coeffecient value is 0.8022549760644999
#
# Dice coeffecient value is 0.8032678256487781
#
# Dice coeffecient value is 0.802459057697153
#
# Dice coeffecient value is 0.8022398589065256
#
# Dice coeffecient value is 0.8026732174351222
#
# Dice coeffecient value is 0.8034542705971277
#
# Dice coeffecient value is 0.8047619047619048
#
# Dice coeffecient value is 0.804474678760393
#
# Dice coeffecient value is 0.8047341899722852
#
# Dice coeffecient value is 0.804469639707735
#
# Dice coeffecient value is 0.8052658100277148
#
# Dice coeffecient value is 0.804572940287226
#
# Dice coeffecient value is 0.8042479213907785
#
# Dice coeffecient value is 0.8031443688586546
#
# Dice coeffecient value is 0.8034089191232049
#
# Dice coeffecient value is 0.8031468883849836
#
# Dice coeffecient value is 0.8059360040312421
#
# Dice coeffecient value is 0.8045527840765936
#
# Dice coeffecient value is 0.8044066515495087
#
# Dice coeffecient value is 0.8051146384479718
#
# Dice coeffecient value is 0.8054245401864449
#
# Dice coeffecient value is 0.8068203577727387
#
# Dice coeffecient value is 0.8076744771982867
#
# Dice coeffecient value is 0.8077802973041068
#
# Dice coeffecient value is 0.807689594356261
#
# Dice coeffecient value is 0.8077097505668934
#
# Dice coeffecient value is 0.8066213151927437
#
# Dice coeffecient value is 0.8065406903502141
#
# Dice coeffecient value is 0.8067069790879314
#
# Dice coeffecient value is 0.8069513731418493
#
# Dice coeffecient value is 0.8066213151927437
#
# Dice coeffecient value is 0.8069942050894432
#
# Dice coeffecient value is 0.8075233056185437
#
# Dice coeffecient value is 0.8090325018896447
#
# Dice coeffecient value is 0.8104686318972033
#
# Dice coeffecient value is 0.81095490047871
#
# Dice coeffecient value is 0.8114688838498362
#
# Dice coeffecient value is 0.812968002015621
#
# Dice coeffecient value is 0.8116654069035022
#
# Dice coeffecient value is 0.81286470143613
#
# Dice coeffecient value is 0.8136785084404132
#
# Dice coeffecient value is 0.8086722096245906
#
# Dice coeffecient value is 0.8090400604686319
#
# Dice coeffecient value is 0.8091206853111615
#
# Dice coeffecient value is 0.8095061728395062
#
# Dice coeffecient value is 0.8102746283698664
#
# Dice coeffecient value is 0.8116956412194507
#
# Dice coeffecient value is 0.8107357016880826
#
# Dice coeffecient value is 0.8156538170823885
#
# Dice coeffecient value is 0.8152103804484757
#
# Dice coeffecient value is 0.8161048122952885
#
# Dice coeffecient value is 0.8169538926681784
#
# Dice coeffecient value is 0.8181582262534643
#
# Dice coeffecient value is 0.8151977828168304
#
# Dice coeffecient value is 0.8191131267321744
#
# Dice coeffecient value is 0.8163441672965482
#
# Dice coeffecient value is 0.8218014613252709
#
# Dice coeffecient value is 0.8219022423784329
#
# Dice coeffecient value is 0.821456286218191
#
# Dice coeffecient value is 0.8210078105316201
#
# Dice coeffecient value is 0.8224187452758881
#
# Dice coeffecient value is 0.8238044847568657
#
# Dice coeffecient value is 0.8247089947089947
#
# Dice coeffecient value is 0.8255353993449231
#
# Dice coeffecient value is 0.8272814310909549
#
# Dice coeffecient value is 0.8262736205593348
#
# Dice coeffecient value is 0.8282212144116906
#
# Dice coeffecient value is 0.8273318216175359
#
# Dice coeffecient value is 0.8281708238851097
#
# Dice coeffecient value is 0.8307482993197279
#
# Dice coeffecient value is 0.8319123204837491
#
# Dice coeffecient value is 0.8300302343159486
#
# Dice coeffecient value is 0.8323532375913328
#
# Dice coeffecient value is 0.8342756361803981
#
# Dice coeffecient value is 0.8341093474426807
#
# Dice coeffecient value is 0.8345830183925422
#
# Dice coeffecient value is 0.8345351473922903
#
# Dice coeffecient value is 0.834673721340388
#
# Dice coeffecient value is 0.8369690098261526
#
# Dice coeffecient value is 0.8354320987654321
#
# Dice coeffecient value is 0.8374855127236079
#
# Dice coeffecient value is 0.8388485764676241
#
# Dice coeffecient value is 0.8389014865205341
#
# Dice coeffecient value is 0.8403300579491055
#
# Dice coeffecient value is 0.839697656840514
#
# Dice coeffecient value is 0.8410707986898464
#
# Dice coeffecient value is 0.8413479465860418
#
# Dice coeffecient value is 0.8419753086419753
#
# Dice coeffecient value is 0.8414386495338876
#
# Dice coeffecient value is 0.8422877299067775
#
# Dice coeffecient value is 0.8429428067523306
#
# Dice coeffecient value is 0.8434819853867473
#
# Dice coeffecient value is 0.8442579994960947
#
# Dice coeffecient value is 0.8449508692365835
#
# Dice coeffecient value is 0.8457117661879566
#
# Dice coeffecient value is 0.8464373897707231
#
# Dice coeffecient value is 0.8472486772486773
#
# Dice coeffecient value is 0.8480146132527084
#
# Dice coeffecient value is 0.8505895691609977
#
# Dice coeffecient value is 0.8497883597883598
#
# Dice coeffecient value is 0.8489317208364827
#
# Dice coeffecient value is 0.8515293524817334
#
# Dice coeffecient value is 0.8524691358024692
#
# Dice coeffecient value is 0.8535777273872512
#
# Dice coeffecient value is 0.8547089947089948
#
# Dice coeffecient value is 0.8570597127739985
#
# Dice coeffecient value is 0.8557974300831444
#
# Dice coeffecient value is 0.8582539682539683
#
# Dice coeffecient value is 0.8595338876291257
#
# Dice coeffecient value is 0.8606928697404888
#
# Dice coeffecient value is 0.8632199546485261
#
# Dice coeffecient value is 0.8620055429579239
#
# Dice coeffecient value is 0.8644116906021668
#
# Dice coeffecient value is 0.8658578987150416
#
# Dice coeffecient value is 0.8670496346686822
#
# Dice coeffecient value is 0.8697278911564625
#
# Dice coeffecient value is 0.8684857646762408
#
# Dice coeffecient value is 0.8710833963214916
#
# Dice coeffecient value is 0.8724263038548753
#
# Dice coeffecient value is 0.8738573948097758
#
# Dice coeffecient value is 0.8753187200806248
#
# Dice coeffecient value is 0.8767397329302091
#
# Dice coeffecient value is 0.882763920382968
#
# Dice coeffecient value is 0.881259763164525
#
# Dice coeffecient value is 0.8797656840513983
#
# Dice coeffecient value is 0.8782741244646006
#
# Dice coeffecient value is 0.8912018140589569
#
# Dice coeffecient value is 0.8870823885109599
#
# Dice coeffecient value is 0.8855832703451751
#
# Dice coeffecient value is 0.8898211136306374
#
# Dice coeffecient value is 0.8885034013605442
#
# Dice coeffecient value is 0.892711010330058
#
# Dice coeffecient value is 0.8970269589317208
#
# Dice coeffecient value is 0.8941093474426808
#
# Dice coeffecient value is 0.9032375913328294
#
# Dice coeffecient value is 0.9000932224741749
#
# Dice coeffecient value is 0.8986495338876291
#
# Dice coeffecient value is 0.8955908289241623
#
# Dice coeffecient value is 0.9016679264298312
#
# Dice coeffecient value is 0.9048954396573444
#
# Dice coeffecient value is 0.88421768707483
#
# Dice coeffecient value is 0.9177021919879063
#
# Dice coeffecient value is 0.9158578987150415
#
# Dice coeffecient value is 0.9085008818342152
#
# Dice coeffecient value is 0.9121390778533636
#
# Dice coeffecient value is 0.9138876291257244
#
# Dice coeffecient value is 0.9103628117913832
#
# Dice coeffecient value is 0.9196321491559587
#
# Dice coeffecient value is 0.9214663643235071
#
# Dice coeffecient value is 0.9067548500881835
#
# Dice coeffecient value is 0.9235273368606702
#
# Dice coeffecient value is 0.9317712270093222
#
# Dice coeffecient value is 0.9355102040816327
#
# Dice coeffecient value is 0.933668430335097
#
# Dice coeffecient value is 0.9391559586797682
#
# Dice coeffecient value is 0.9296699420508945
#
# Dice coeffecient value is 0.937488032249937
#
# Dice coeffecient value is 0.9275837742504409
#
# Dice coeffecient value is 0.9255353993449231
#
# Dice coeffecient value is 0.9427059712773999
#
# Dice coeffecient value is 0.9409095490047871
#
# Dice coeffecient value is 0.9442529604434367
#
# Dice coeffecient value is 0.9503703703703704
#
# Dice coeffecient value is 0.9473494583018393
#
# Dice coeffecient value is 0.9516931216931217
#
# Dice coeffecient value is 0.9458327034517511
#
# Dice coeffecient value is 0.9489821113630638
#
# Dice coeffecient value is 0.9530788611740992
#
# Dice coeffecient value is 0.9544520030234316
#
# Dice coeffecient value is 0.9570874275636181
#
# Dice coeffecient value is 0.9558503401360544
#
# Dice coeffecient value is 0.958546233308138
#
# Dice coeffecient value is 0.9597782816830436
#
# Dice coeffecient value is 0.9662333081380701
#
# Dice coeffecient value is 0.9650566893424036
#
# Dice coeffecient value is 0.9636961451247166
#
# Dice coeffecient value is 0.9610758377425044
#
# Dice coeffecient value is 0.9677273872511968
#
# Dice coeffecient value is 0.9701612496850592
#
# Dice coeffecient value is 0.9689594356261023
#
# Dice coeffecient value is 0.9623255228017132
#
# Dice coeffecient value is 0.9807357016880827
#
# Dice coeffecient value is 0.9754446963970773
#
# Dice coeffecient value is 0.9793046107331822
#
# Dice coeffecient value is 0.972663139329806
#
# Dice coeffecient value is 0.9766112370874276
#
# Dice coeffecient value is 0.9780297304106828
#
# Dice coeffecient value is 0.9739657344419249
#
# Dice coeffecient value is 0.9713504661123709
#
# Dice coeffecient value is 0.9821315192743764
#
# Dice coeffecient value is 0.9834870244394054
#
# Dice coeffecient value is 0.9847971781305115
#
# Dice coeffecient value is 0.986230788611741
#
# Dice coeffecient value is 0.9899193751574704
#
# Dice coeffecient value is 0.9873771730914588
#
# Dice coeffecient value is 0.9925724363819602
#
# Dice coeffecient value is 0.991257243638196
#
# Dice coeffecient value is 0.993814562862182
#
# Dice coeffecient value is 0.9886898463088939
#
# Dice coeffecient value is 0.9950113378684807
#
# Dice coeffecient value is 0.9959637188208617
#
# Dice coeffecient value is 0.996883345930965
#
# Dice coeffecient value is 0.9983270345175107
#
# Dice coeffecient value is 0.9977676996724616
#
# Dice coeffecient value is 0.9985714285714286
#
# Dice coeffecient value is 0.9985386747291509
#
# Dice coeffecient value is 0.9985512723607962
#
# Dice coeffecient value is 0.9985613504661124
#
# Dice coeffecient value is 0.9985336356764928
#
# Dice coeffecient value is 0.9985185185185185
#
# Dice coeffecient value is 0.9985210380448476
#
# Dice coeffecient value is 0.9984152179390274
#
# Dice coeffecient value is 0.9984328546233309
#
# Dice coeffecient value is 0.9985059208868733
#
# Dice coeffecient value is 0.9984051398337113
#
# Dice coeffecient value is 0.9983950617283951
#
# Dice coeffecient value is 0.9984227765180146
#
# Dice coeffecient value is 0.9984681279919375
#
# Dice coeffecient value is 0.9984857646762408
#
# Dice coeffecient value is 0.998390022675737
#
# Dice coeffecient value is 0.9983648274124465
#
# Dice coeffecient value is 0.9982665658856135
#
# Dice coeffecient value is 0.9983597883597883
#
# Dice coeffecient value is 0.9983749055177626
#
# Dice coeffecient value is 0.9982262534643487
#
# Dice coeffecient value is 0.9982665658856135
#
# Dice coeffecient value is 0.9955026455026456
#
# Dice coeffecient value is 0.9949433106575963
#
# Dice coeffecient value is 0.9983144368858654
#
# Dice coeffecient value is 0.9982791635172588
#
# Dice coeffecient value is 0.9561577223481985
#
# Dice coeffecient value is 0.9898311917359537
#
# Dice coeffecient value is 0.9846056941295036
#
# Dice coeffecient value is 0.98050390526581
#
# Dice coeffecient value is 0.9901436130007558
#
# Dice coeffecient value is 0.8915646258503401
#
# Dice coeffecient value is 0.9697581254724111
#
# Dice coeffecient value is 0.9335500125976316
#
# Dice coeffecient value is 0.8600352733686067
#
# Dice coeffecient value is 0.8194305870496347
#
# Dice coeffecient value is 0.8120408163265306
#
# Dice coeffecient value is 0.7450415721844293
#
# Dice coeffecient value is 0.7628470647518266
#
# Dice coeffecient value is 0.7943461829176115
#
# Dice coeffecient value is 0.7759284454522549
#
# Dice coeffecient value is 0.7609246661627614
#
# Dice coeffecient value is 0.7629226505416982
#
# Dice coeffecient value is 0.7627387251196776
#
# Dice coeffecient value is 0.7498614260519022
#
# Dice coeffecient value is 0.7716427311665407
#
# Dice coeffecient value is 0.7719652305366591
#
# Dice coeffecient value is 0.7785512723607961
#
# Dice coeffecient value is 0.790854119425548
#
# Dice coeffecient value is 0.7883572688334594
#
# Dice coeffecient value is 0.7739455782312925
#
# Dice coeffecient value is 0.7973973293020912
#
# Dice coeffecient value is 0.8275988914084152
#
# Dice coeffecient value is 0.8107306626354246
#
# Dice coeffecient value is 0.8505467372134039
#
# Dice coeffecient value is 0.8801410934744268
#
# Dice coeffecient value is 0.9047770219198791
#
# Dice coeffecient value is 0.9333585285966238
#
# Dice coeffecient value is 0.99758629377677
#
# Dice coeffecient value is 0.98960191484001
#
# Dice coeffecient value is 0.9646334089191232
#
# Dice coeffecient value is 0.9977551020408163
#
# Dice coeffecient value is 1.0
#
# Dice coeffecient value is 0.997591332829428
#
# Dice coeffecient value is 0.9984681279919375
#
# Dice coeffecient value is 0.9978130511463845
#
# Dice coeffecient value is 0.997689594356261
#
# Dice coeffecient value is 0.9979264298311917
#
# Dice coeffecient value is 0.9948374905517763
#
# Dice coeffecient value is 0.9913328294280676
#
# Dice coeffecient value is 0.9957470395565634
#
# Dice coeffecient value is 0.9969639707734946
#
# Dice coeffecient value is 0.986029226505417
#
# Dice coeffecient value is 0.9773796926177879
#
# Dice coeffecient value is 0.9587528344671202
#
# Dice coeffecient value is 0.9444897959183673
#
# Dice coeffecient value is 0.9250340136054421
#
# Dice coeffecient value is 0.9068253968253969
#
# Dice coeffecient value is 0.8370949861426051
#
# Dice coeffecient value is 0.7947115142353237
#
# Dice coeffecient value is 0.7960745779793399
#
# Dice coeffecient value is 0.8545452254976065
#
# Dice coeffecient value is 0.7977047115142353
#
# Dice coeffecient value is 0.7990602166792643
#
# Dice coeffecient value is 0.7998286722096246
#
# Dice coeffecient value is 0.8017737465356513
#
# Dice coeffecient value is 0.7972184429327287
#
# Dice coeffecient value is 0.7971126228269085
#
# Dice coeffecient value is 0.7995540438397581
#
# Dice coeffecient value is 0.7974326026706979
#
# Dice coeffecient value is 0.7998815822625347
#
# Dice coeffecient value is 0.799904257999496
#
# Dice coeffecient value is 0.7987553539934492
#
# Dice coeffecient value is 0.7968279163517259
#
# Dice coeffecient value is 0.7973091458805744
#
# Dice coeffecient value is 0.7986218190980096
#
# Dice coeffecient value is 0.8011010330057949
#
# Dice coeffecient value is 0.8044595616024187
#
# Dice coeffecient value is 0.8077601410934744
#
# Dice coeffecient value is 0.8079793398841018
#
# Dice coeffecient value is 0.8088813303099017
#
# Dice coeffecient value is 0.8126505416981608
#
# Dice coeffecient value is 0.8192340639959688
#
# Dice coeffecient value is 0.8157923910304863
#
# Dice coeffecient value is 0.8239808515998992
#
# Dice coeffecient value is 0.8302066011589821
#
# Dice coeffecient value is 0.8366918619299571
#
# Dice coeffecient value is 0.8438145628621819
#
# Dice coeffecient value is 0.8520937263794407
#
# Dice coeffecient value is 0.8600629881582262
#
# Dice coeffecient value is 0.8698261526832956
#
# Dice coeffecient value is 0.8778458049886622
#
# Dice coeffecient value is 0.8848828420256992
#
# Dice coeffecient value is 0.8927714789619552
#
# Dice coeffecient value is 0.9024338624338625
#
# Dice coeffecient value is 0.9232955404383976
#
# Dice coeffecient value is 0.932763920382968
#
# Dice coeffecient value is 0.9135424540186445
#
# Dice coeffecient value is 0.9527488032249937
#
# Dice coeffecient value is 0.942562358276644
#
# Dice coeffecient value is 0.9625547996976569
#
# Dice coeffecient value is 0.9741899722852104
#
# Dice coeffecient value is 0.9974452003023432
#
# Dice coeffecient value is 0.9851599899218947
#
# Dice coeffecient value is 0.997835726883346
#
# Dice coeffecient value is 0.99899218946838
#
# Dice coeffecient value is 0.9982564877802973
#
# Dice coeffecient value is 0.9980272108843538
#
# Dice coeffecient value is 0.9981758629377677
#
# Dice coeffecient value is 0.9914008566389518
#
# Dice coeffecient value is 0.9895238095238095
#
# Dice coeffecient value is 0.9922171831695641
#
# Dice coeffecient value is 0.9970319979843789
#
# Dice coeffecient value is 0.9968631897203326
#
# Dice coeffecient value is 0.9943008314436886
#
# Dice coeffecient value is 0.9930259511211892
#
# Dice coeffecient value is 0.993018392542202
#
# Dice coeffecient value is 0.9928042328042328
#
# Dice coeffecient value is 0.9945427059712774
#
# Dice coeffecient value is 0.994570420760897
#
# Dice coeffecient value is 0.9892365835222978
#
# Dice coeffecient value is 0.9735474930713026
#
# Dice coeffecient value is 0.9375031494079114
#
# Dice coeffecient value is 0.9537969261778786
#
# Dice coeffecient value is 0.906581002771479
#
# Dice coeffecient value is 0.8792214663643235
#
# Dice coeffecient value is 0.8490576971529352
#
# Dice coeffecient value is 0.842612748803225
#
# Dice coeffecient value is 0.8364625850340136
#
# Dice coeffecient value is 0.8315243134290753
#
# Dice coeffecient value is 0.8334089191232048
#
# Dice coeffecient value is 0.8322398589065255
#
# Dice coeffecient value is 0.8315923406399597
#
# Dice coeffecient value is 0.8376543209876544
#
# Dice coeffecient value is 0.8420307382212144
#
# Dice coeffecient value is 0.8458830939783321
#
# Dice coeffecient value is 0.8571252204585538
#
# Dice coeffecient value is 0.8630864197530864
#
# Dice coeffecient value is 0.8731746031746032
#
# Dice coeffecient value is 0.9303880070546737
#
# Dice coeffecient value is 0.9462585034013605
#
# Dice coeffecient value is 0.97427059712774
#
# Dice coeffecient value is 0.8994079113126732
#
# Dice coeffecient value is 0.9133232552280172
#
# Dice coeffecient value is 0.8853388762912573
#
# Dice coeffecient value is 0.9602317964222726
#
# Dice coeffecient value is 0.9855026455026455
#
# Dice coeffecient value is 0.997687074829932
#
# Dice coeffecient value is 0.9936583522297808
#
# Dice coeffecient value is 0.9984101788863694
#
# Dice coeffecient value is 0.9924011085915848
#
# Dice coeffecient value is 0.998596623834719
#
# Dice coeffecient value is 0.9976618795666414
#
# Dice coeffecient value is 0.9970597127739985
#
# Dice coeffecient value is 0.9361375661375662
#
# Dice coeffecient value is 0.9575157470395566
#
# Dice coeffecient value is 0.970246913580247
#
# Dice coeffecient value is 0.9839304610733182
#
# Dice coeffecient value is 0.9201864449483497
#
# Dice coeffecient value is 0.8998815822625347
#
# Dice coeffecient value is 0.8846283698664651
#
# Dice coeffecient value is 0.7745880574452003
#
# Dice coeffecient value is 0.7958100277147896
#
# Dice coeffecient value is 0.7854497354497354
#
# Dice coeffecient value is 0.8337037037037037
#
# Dice coeffecient value is 0.7871227009322247
#
# Dice coeffecient value is 0.858997228521038
#
# Dice coeffecient value is 0.7931065759637188
#
# Dice coeffecient value is 0.7903502141597379
#
# Dice coeffecient value is 0.7959057697152935
#
# Dice coeffecient value is 0.7914865205341396
#
# Dice coeffecient value is 0.7941698160745779
#
# Dice coeffecient value is 0.798641975308642
#
# Dice coeffecient value is 0.7922801713277904
#
# Dice coeffecient value is 0.7916301335348954
#
# Dice coeffecient value is 0.8020987654320988
#
# Dice coeffecient value is 0.8098286722096246
#
# Dice coeffecient value is 0.7950365331317713
#
# Dice coeffecient value is 0.8043789367598891
#
# Dice coeffecient value is 0.8376996724615772
#
# Dice coeffecient value is 0.8306903502141597
#
# Dice coeffecient value is 0.8542076089695138
#
# Dice coeffecient value is 0.8242529604434367
#
# Dice coeffecient value is 0.9246460065507685
#
# Dice coeffecient value is 0.8995137314184933
#
# Dice coeffecient value is 0.9458982111363063
#
# Dice coeffecient value is 0.8155102040816327
#
# Dice coeffecient value is 0.8736381960191484
#
# Dice coeffecient value is 0.9636860670194004
#
# Dice coeffecient value is 0.9943965734441925
#
# Dice coeffecient value is 0.9118140589569161
#
# Dice coeffecient value is 0.8277374653565129
#
# Dice coeffecient value is 0.8657898715041572
#
# Dice coeffecient value is 0.9981582262534644
#
# Dice coeffecient value is 0.9823280423280424
#
# Dice coeffecient value is 0.8499168556311414
#
# Dice coeffecient value is 0.8382464096749811
#
# Dice coeffecient value is 0.9982035777273872
#
# Dice coeffecient value is 0.8901184177374654
#
# Dice coeffecient value is 0.8203703703703704
#
# Dice coeffecient value is 0.8300604686318972
#
# Dice coeffecient value is 0.826785084404132
#
# Dice coeffecient value is 0.817137818090199
#
# Dice coeffecient value is 0.8147493071302595
#
# Dice coeffecient value is 0.8236911060720584
#
# Dice coeffecient value is 0.8309700176366843
#
# Dice coeffecient value is 0.832108843537415
#
# Dice coeffecient value is 0.8332905013857395
#
# Dice coeffecient value is 0.8352809271856891
#
# Dice coeffecient value is 0.8400453514739229
#
# Dice coeffecient value is 0.8402695893172084
#
# Dice coeffecient value is 0.8422171831695642
#
# Dice coeffecient value is 0.8408667170571933
#
# Dice coeffecient value is 0.8484278155706727
#
# Dice coeffecient value is 0.8410582010582011
#
# Dice coeffecient value is 0.8436079617031998
#
# Dice coeffecient value is 0.8451801461325271
#
# Dice coeffecient value is 0.8431368102796675
#
# Dice coeffecient value is 0.8508868732678256
#
# Dice coeffecient value is 0.8546586041824137
#
# Dice coeffecient value is 0.8602292768959435
#
# Dice coeffecient value is 0.8578004535147392
#
# Dice coeffecient value is 0.8644746787603931
#
# Dice coeffecient value is 0.8667044595616025
#
# Dice coeffecient value is 0.8741143864953389
#
# Dice coeffecient value is 0.877843285462333
#
# Dice coeffecient value is 0.8705643738977072
#
# Dice coeffecient value is 0.8823910304862685
#
# Dice coeffecient value is 0.8878357268833459
#
# Dice coeffecient value is 0.8942781557067271
#
# Dice coeffecient value is 0.909501133786848
#
# Dice coeffecient value is 0.9014159737969262
#
# Dice coeffecient value is 0.9208087679516251
#
# Dice coeffecient value is 0.9141118669690098
#
# Dice coeffecient value is 0.9280322499370118
#
# Dice coeffecient value is 0.9574300831443688
#
# Dice coeffecient value is 0.9482338120433359
#
# Dice coeffecient value is 1.0
#
# Dice coeffecient value is 0.9393751574703956
#
# Dice coeffecient value is 1.0
#
# Dice coeffecient value is 1.0
#
# Dice coeffecient value is 1.0
#
# Dice coeffecient value is 1.0
#
# Dice coeffecient value is 1.0
#
# Dice coeffecient value is 1.0
#
# Dice coeffecient value is 1.0
#
# Dice coeffecient value is 0.9998463088939279
#
# Dice coeffecient value is 0.998745275888133
#
# Dice coeffecient value is 0.9979768203577727
#
# Dice coeffecient value is 0.9886067019400353
#
# Dice coeffecient value is 0.9910178886369363
#
# Dice coeffecient value is 0.9856462585034014
#
# Dice coeffecient value is 0.9822549760644999
#
# Dice coeffecient value is 0.9952708490803729
#
# Dice coeffecient value is 0.9789166036785084
#
# Dice coeffecient value is 0.9969261778785589
#
# Dice coeffecient value is 0.966533131771227
#
# Dice coeffecient value is 0.9934719072814311
#
# Dice coeffecient value is 0.9735500125976316
#
# Dice coeffecient value is 0.8884177374653565
#
# Dice coeffecient value is 0.8706349206349207
#
# Dice coeffecient value is 0.8691786344167296
#
# Dice coeffecient value is 0.920602166792643
#
# Dice coeffecient value is 0.9503149407911312
#
# Dice coeffecient value is 0.9415444696397077
#
# Dice coeffecient value is 0.8724036281179138
#
# Dice coeffecient value is 0.9584278155706727
#
# Dice coeffecient value is 0.9083799445704207
#
# Dice coeffecient value is 0.9310758377425045
#
# Dice coeffecient value is 0.8750541698160745
#
# Dice coeffecient value is 0.8804484756865709
#
# Dice coeffecient value is 0.8746409674981104
#
# Dice coeffecient value is 0.873013353489544
#
# Dice coeffecient value is 0.8817561098513479
#
# Dice coeffecient value is 0.8780020156210633
#
# Dice coeffecient value is 0.8722751322751323
#
# Dice coeffecient value is 0.881506676744772
#
# Dice coeffecient value is 0.8815469891660368
#
# Dice coeffecient value is 0.881106072058453
#
# Dice coeffecient value is 0.8692542202066011
#
# Dice coeffecient value is 0.8762131519274377
#
# Dice coeffecient value is 0.8785588309397834
#
# Dice coeffecient value is 0.8733232552280171
#
# Dice coeffecient value is 0.881302595112119
#
# Dice coeffecient value is 0.8752355757117661
#
# Dice coeffecient value is 0.8705366591080876
#
# Dice coeffecient value is 0.8671504157218443
#
# Dice coeffecient value is 0.8672537163013353
#
# Dice coeffecient value is 0.8663013353489544
#
# Dice coeffecient value is 0.8656462585034014
#
# Dice coeffecient value is 0.8638044847568657
#
# Dice coeffecient value is 0.8664902998236331
#
# Dice coeffecient value is 0.8643109095490048
#
# Dice coeffecient value is 0.8651574703955657
#
# Dice coeffecient value is 0.8663391282438901
#
# Dice coeffecient value is 0.8742857142857143
#
# Dice coeffecient value is 0.8675081884605694
#
# Dice coeffecient value is 0.8709322247417486
#
# Dice coeffecient value is 0.8757394809775763
#
# Dice coeffecient value is 0.8807709750566893
#
# Dice coeffecient value is 0.8752834467120182
#
# Dice coeffecient value is 0.8873796926177878
#
# Dice coeffecient value is 0.8835752078609221
#
# Dice coeffecient value is 0.8784404132023179
#
# Dice coeffecient value is 0.876586041824137
#
# Dice coeffecient value is 0.8944469639707735
#
# Dice coeffecient value is 0.8904963466868229
#
# Dice coeffecient value is 0.8988485764676241
#
# Dice coeffecient value is 0.9137616528092719
#
# Dice coeffecient value is 0.9080120937263795
#
# Dice coeffecient value is 0.9269488536155203
#
# Dice coeffecient value is 0.9031746031746032
#
# Dice coeffecient value is 0.9201738473167045
#
# Dice coeffecient value is 0.9416906021667927
#
# Dice coeffecient value is 0.9343864953388763
#
# Dice coeffecient value is 0.9481481481481482
#
# Dice coeffecient value is 0.9555555555555556
#
# Dice coeffecient value is 0.9625472411186697
#
# Dice coeffecient value is 0.9694129503653314
#
# Dice coeffecient value is 0.9905442176870748
#
# Dice coeffecient value is 0.9969967246157723
#
# Dice coeffecient value is 0.9838750314940791
#
# Dice coeffecient value is 0.9770949861426051
#
# Dice coeffecient value is 0.9984530108339632
#
# Dice coeffecient value is 0.9984026203073822
#
# Dice coeffecient value is 0.9985084404132023
#
# Dice coeffecient value is 0.9985613504661124
#
# Dice coeffecient value is 0.9986243386243386
#
# Dice coeffecient value is 0.9975560594608214
#
# Dice coeffecient value is 0.9986848072562359
#
# Dice coeffecient value is 0.9987780297304106
#
# Dice coeffecient value is 0.9984504913076342
#
# Dice coeffecient value is 0.9222222222222223
#
# Dice coeffecient value is 0.9074552784076594
#
# Dice coeffecient value is 0.8977903754094231
#
# Dice coeffecient value is 0.8866742252456539
#
# Dice coeffecient value is 0.8748425296044343
#
# Dice coeffecient value is 0.8652229780801209
#
# Dice coeffecient value is 0.8577651801461326
#
# Dice coeffecient value is 0.8452607709750567
#
# Dice coeffecient value is 0.8502141597379692
#
# Dice coeffecient value is 0.9969236583522297
#
# Dice coeffecient value is 0.9969690098261527
#
# Dice coeffecient value is 0.9971151423532376
#
# Dice coeffecient value is 0.9968984630889393
#
# Dice coeffecient value is 0.9964726631393298
#
# Dice coeffecient value is 0.9956361803980852
#
# Dice coeffecient value is 0.9958679768203578
#
# Dice coeffecient value is 0.995726883345931
#
# Dice coeffecient value is 0.9955228017132779
#
# Dice coeffecient value is 0.9962131519274376
#
# Dice coeffecient value is 0.9944620811287478
#
# Dice coeffecient value is 0.9955555555555555
#
# Dice coeffecient value is 0.9939405391786345
#
# Dice coeffecient value is 0.9937238599143361
#
# Dice coeffecient value is 0.9937112622826908
#
# Dice coeffecient value is 0.993665910808768
#
# Dice coeffecient value is 0.9930511463844797
#
# Dice coeffecient value is 0.9926807760141093
#
# Dice coeffecient value is 0.9926253464348702
#
# Dice coeffecient value is 0.9923078861174099
#
# Dice coeffecient value is 0.9971982867220962
#
# Dice coeffecient value is 0.9975434618291761
#
# Dice coeffecient value is 0.9977425044091711

# %%
dicee = np.array(dicee)

# %%
#len = len(dicee)
print("Number of Values is", len)

# Taking average of dice values
av=np.mean(dicee)
print ("average dice values is", av)

# Taking maximuim and minimuim of dice values
mx=np.max(dicee)
print ("maximuim dice values is", mx)

mn=np.min(dicee)
print ("minimuim dice values is", mn)
# Out:
# Number of Values is 829
# average dice values is 0.8931156085719818
# maximuim dice values is 1.0
# minimuim dice values is 0.7450415721844293

# %% [markdown]
# ## Intersection over Union Measure of performance

# %%
def bb_intersection_over_union(boxA, boxB):
	# determine the (x, y)-coordinates of the intersection rectangle
	xA = max(boxA[0], boxB[0])
	yA = max(boxA[1], boxB[1])
	xB = min(boxA[2], boxB[2])
	yB = min(boxA[3], boxB[3])
	# compute the area of intersection rectangle
	interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
	# compute the area of both the prediction and ground-truth
	# rectangles
	boxAArea = (boxA[2] - boxA[0] + 1) * (boxA[3] - boxA[1] + 1)
	boxBArea = (boxB[2] - boxB[0] + 1) * (boxB[3] - boxB[1] + 1)
	# compute the intersection over union by taking the intersection
	# area and dividing it by the sum of prediction + ground-truth
	# areas - the interesection area
	iou = interArea / float(boxAArea + boxBArea - interArea)
	# return the intersection over union value
	return iou

# %%
## Ground Truth Mask
img = cv2.imread('/content/gdrive/MyDrive/Segmentation/slices/mask/t0-slice012_z.png')

hist, hist_centers = histogram(img)
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(img, cmap=plt.cm.gray)
axes[0].axis('off')
axes[0].set_title('Ground Truth')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('Ground Truth Grey Values')

#print(img)
img = np.asarray(img).astype(np.bool)
#print(img)
print(img.shape)
#print('_'*40)

## Predicted mask
img2 = cv2.imread('/content/gdrive/MyDrive/Segmentation/slices/img/t0-slice012_z.png')
img2 = cv2.subtract(250, img2)

hist, hist_centers = histogram(img2)
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(img2, cmap=plt.cm.gray)
axes[0].axis('off')
axes[0].set_title('Predicted Mask')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('Pridited mask Grey Values')

#print(img2)
img2 = np.asarray(img2).astype(np.bool)

#print(img2)
print(img2.shape)
#print('%'*40)

value = bb_intersection_over_union(img, img2)
print("IoU", value)
# Out:
# (630, 630, 3)
# (630, 630, 3)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-fea012fbe874> in <module>()
#      35 #print('%'*40)
#      36
# ---> 37 value = bb_intersection_over_union(img, img2)
#      38 print("IoU", value)
#
# <ipython-input-145-2b238ff787ca> in bb_intersection_over_union(boxA, boxB)
#       1 def bb_intersection_over_union(boxA, boxB):
#       2         # determine the (x, y)-coordinates of the intersection rectangle
# ----> 3         xA = max(boxA[0], boxB[0])
#       4         yA = max(boxA[1], boxB[1])
#       5         xB = min(boxA[2], boxB[2])
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
